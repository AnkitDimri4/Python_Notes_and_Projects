# %% [markdown]
# #### **C:\Users\ANKIT DIMRI\.vscode\Complete Programming\Python program\Python tutedude\DJANGO**
# # **Project -**
# - **1. test_1**
#
# - **2. hellowrold**
#
# - **3. Temp**
#
# - **4. DTL**
#
# - **5. login**
#
# - **6. login_1**
#
# - **7. web**
#
# - **8. config**
#
# - **9. website**

# %% [markdown]
# ______________________
# # **DJANGO -[FrameWork]**
# ______________________
# -    Django makes it easier to build better web apps more quickly and with less code.
#         - Ridiculously fast
#         - Reassuringly Secure
#         - Exceedingly scalable
#
# - [Web Development ---> Frame Work]
#     - Frame Work --> Set of codes that are already predefined
#         - Web frame Work --> Web Development
#             - Installing process ..
#                 - tzdata, sqlparse, asgiref, django
#
#
#     djangoproject.com
# -
#     - [1.Creating project](#1creating-project)<br>
#     - [2.Creating an app](#2creating-an-app)<br>
#     - [3.3.Creating files using DJANGO ](#3creating-files-using-django)<br>
#     - [4.User registration(part)]()<br>
#     - [4.Django Template Language](#4django-template-language)<br>
#     - [5.Adding Numbers :-](#5adding-numbers)<br>
#     - [GET vs POST](#get-vs-post)<br>
#     - [MVT](#mvt)<br>
#     - [Static Files]()<br>
#     - [Static Files](#static-files)<br>
#     - [User-Registeration  And Login redirect](#user-registeration-and-login-redirect)<br>
#     - [LOGOUT FORMAT](#logout-format)<br>
#     - [fORMS WEB/WEBapp](#forms-webwebapp)<br>
#     - [CREATING YOUR OWN BLOG](#creating-your-own-blog)<br>
#     - []()<br>
#     - []()<br>
#     **pip install Django**
#     >https://sqlitebrowser.org/dl/
#     for dbsqlite

# %% [markdown]
# # 1. **createproject**
# - **django-admin startproject [blog]- project_name**
# - **then create the app**
#     - **python manage.py startapp [app_name]**
# - **then migrate the data**
#     - **[python manage.py makemigrations/migrate]**
#         - **ctrl+c to terminate the program**
#
# - [![image.png](attachment:image.png)]

# %% [markdown]
# ### 1.Creating project
# -
#     -
#     - django-admin --version to check the version
#     - django-admin ro check the subcommands :
#         -   check,    compilemessages,    createcachetable,   dbshell,   diffsettings,  dumpdata, flush,   inspectdb, loaddata,    makemessages,   makemigrations,    migrate,    optimizemigration,  runserver,    sendtestemail,  shell,    showmigrations, sqlflush,    sqlmigrate, sqlsequencereset,    squashmigrations,   startapp,  startproject, test,    testserver,
#
#         - django-admin startproject test_1
#         - goto the file cd with file name
#         - and type
#                 - python file_name runserver
#                     - shows the result like this
#
#
# - You have 18 unapplied migration(s). Your project may not work properly until you apply the migrations for app(s): admin, auth, contenttypes, sessions.
# - Run 'python manage.py migrate' to apply them.
# - January 04, 2023 - 18:50:19
# - Django version 4.1.5, using settings 'test_1.settings'
# - Starting development server at http://127.0.0.1:8000/
# - Quit the server with CTRL-BREAK.
# -
#     - then copy the 8000 and type in new tab with localhost:8000 or whatever the number
#         -
#         ![Screenshot_20230105_121908.png](attachment:Screenshot_20230105_121908.png)
#
#
# - **Quit the server with CTRL-BREAK. If you want to break the server then press ctrl + c**

# %% [markdown]
# ### 2.Creating an app
# -
#     - **python manage.py migrate to check the migrate files**  then
#
#     - **python manage.py startapp testapp [to create the app in the DJANGO file folder]**
#     - C:\Users\ANKIT DIMRI\.vscode\Complete Programming\Python program\Python tutedude\DJANGO\test_1>python manage.py runserver
# -
#     -
#         -
#             - Watching for file changes with StatReloader
#             - Performing system checks...
#             - System check identified no issues (0 silenced).
#             - January 05, 2023 - 12:47:18
#             - Django version 4.1.5, using settings 'test_1.settings'
#             - Starting development server at http://127.0.0.1:8000/
#             - Quit the server with CTRL-BREAK.
#         - Then we can see there is no issue which all are shows in upper cases
#
# -
#     -
#     -  for creating the user name and other details
#         - C:\Users\ANKIT DIMRI\.vscode\Complete Programming\Python program\Python tutedude\DJANGO\test_1>python - - **manage.py createsuperuser**
#         - Username (leave blank to use 'ankitdimri'): testuser
#         - Email address:
#         - Password:
#         - Password (again):
#         - This password is too short. It must contain at least 8 characters.
#         - This password is too common.
#         - Bypass password validation and create user anyway? [y/N]: n
#         - Password:
#         - Password (again):
#         - Superuser created successfully.
#         - C:\Users\ANKIT DIMRI\.vscode\Complete Programming\Python program\Python tutedude\DJANGO\test_1>
#             - password - micro1234#
#         - jango-admin startproject helloworld
#         - python manage.py startapp helloapp

# %% [markdown]
# # 3.Creating files using DJANGO  Helloworld
# - first goto views.py and wrtie the same line program
#     -  views.py
#
#
#         - **from django.shortcuts import render**
#
# - [![Screenshot_20230105_154733.png](attachment:Screenshot_20230105_154733.png)]
#
# - **then goto the settngs in INSTALLED_APPS  AND type in the 'filename' or function name**
#     - [![Screenshot_20230105_155148.png](attachment:Screenshot_20230105_155148.png)]
# -  then goto the **urls.py**
#     - [![Screenshot_20230105_154634.png](attachment:Screenshot_20230105_154634.png)]

# %% [markdown]
# - **django-admin startproject login**
# - **python manage.py startapp accounts**
#     - [![Screenshot_20230105_155402.png](attachment:Screenshot_20230105_155402.png)]
# - create the directory inside the accounts one folder templates
# - create one other folder registration one file inside the folder register.html and one file in the templates index.html
# <br>
#
# - **index.html**
#     ![Screenshot_20230105_153751.png](attachment:Screenshot_20230105_153751.png)
# -  **register.html** <br>
#     ![Screenshot_20230105_153849.png](attachment:Screenshot_20230105_153849.png)
# -
# - then copy the urls files from login to accounts and write the details
# - **login urls** - [![Screenshot_20230105_154230.png](attachment:Screenshot_20230105_154230.png)]
# - **accounts urls** - [![Screenshot_20230105_154320.png](attachment:Screenshot_20230105_154320.png)]
# -

# %% [markdown]
# - **Username: djangogo12**
# - **Password: asdf12#@#**
# - http://127.0.0.1:8000/admin/login/?next=/admin/
#     - goto the login info
#
# - 1. **first create the .html file**
#     - [![Screenshot_20230105_173039.png](attachment:Screenshot_20230105_173039.png)]
# - 2. **goto to views.py**
#     -  [![Screenshot_20230105_172959.png](attachment:Screenshot_20230105_172959.png)]
# - 3. **goto to the settings.py and write the Templates and installed fn**
#     [![Screenshot_20230105_173013.png](attachment:Screenshot_20230105_173013.png)]
# - 4. **goto ulrs.py**
#     - [![Screenshot_20230105_173023.png](attachment:Screenshot_20230105_173023.png)]

# %% [markdown]
# # **4.Django Template  Language -:**

# %% [markdown]
# - **django-admin startproject DTL**
# - **python manage.py startapp Design**
# - **python manage.py migrate**
# - **python mangae.py runserver**
#
#     - first we type the templete file in the html format
#         - [![Screenshot_20230106_135207.png](attachment:Screenshot_20230106_135207.png)]
#     - goto the views file
#         - [![Screenshot_20230106_135240.png](attachment:Screenshot_20230106_135240.png)]
#     -  goto the  settings file
#         - [![Screenshot_20230106_135126.png](attachment:Screenshot_20230106_135126.png)]
#         - [![Screenshot_20230106_135149.png](attachment:Screenshot_20230106_135149.png)]
#     - goto the urls file
#         - [![Screenshot_20230106_135255.png](attachment:Screenshot_20230106_135255.png)]
#     - how look like the directory
#         - [![Screenshot_20230106_135311.png](attachment:Screenshot_20230106_135311.png)]

# %% [markdown]
# # **5.Adding Numbers :-**

# %% [markdown]
# -
#     - [![Screenshot_20230106_151723.png](attachment:Screenshot_20230106_151723.png)]
# -
#     - [![Screenshot_20230106_151731.png](attachment:Screenshot_20230106_151731.png)]
# -
#     - [![Screenshot_20230106_151738.png](attachment:Screenshot_20230106_151738.png)]
# -
#     - [![Screenshot_20230106_151758.png](attachment:Screenshot_20230106_151758.png)]
# -
#     - [![Screenshot_20230106_151807.png](attachment:Screenshot_20230106_151807.png)]

# %% [markdown]
# # **GET vs POST**

# %% [markdown]
# - CSRF verification failed. Request aborted.
#     - Cross Site Request Forgery, or when Django’s CSRF mechanism
#
# - if u want to fit some data through the internet just go with the GET
# - but if u want to data just use the post
# - [![Screenshot_20230106_154041.png](attachment:Screenshot_20230106_154041.png)]
# - [![Screenshot_20230106_154130.png](attachment:Screenshot_20230106_154130.png)]
# - [![Screenshot_20230106_154321.png](attachment:Screenshot_20230106_154321.png)] Without any complicated Urls

# %% [markdown]
# # **MVT**

# %% [markdown]
# - [![Screenshot_20230107_103359.png](attachment:Screenshot_20230107_103359.png)]
# - [![Screenshot_20230107_103942.png](attachment:Screenshot_20230107_103942.png)]

# %% [markdown]
# # **Static Files**

# %% [markdown]
# - [ First download the template from https://startbootstrap.com/themes  and https://colorlib.com/ ]
# #
# first goto the folder and copy the .html file into the template and then copy the js css and assets other files into the startapp folder
# - [![Screenshot_20230107_140107.png](attachment:Screenshot_20230107_140107.png)]
# - first goto the urls in static
# - [![Screenshot_20230107_140635.png](attachment:Screenshot_20230107_140635.png)]
# - goto the urls in DTL
# - [![Screenshot_20230107_140648.png](attachment:Screenshot_20230107_140648.png)]
# - then goto the settings
# - [![Screenshot_20230107_141049.png](attachment:Screenshot_20230107_141049.png)]<br>[![Screenshot_20230107_141059.png](attachment:Screenshot_20230107_141059.png)]
# - In html file
# - [![Screenshot_20230107_141224.png](attachment:Screenshot_20230107_141224.png)]
# - [![Screenshot_20230107_141247.png](attachment:Screenshot_20230107_141247.png)]
# - [![Screenshot_20230107_141323.png](attachment:Screenshot_20230107_141323.png)]

# %% [markdown]
# # **User-Registeration  And Login redirect**

# %% [markdown]
# - []
# - [![Screenshot_20230107_162604.png](attachment:Screenshot_20230107_162604.png)]
# - []
# - [![Screenshot_20230107_162612.png](attachment:Screenshot_20230107_162612.png)]
# - []
# - [![Screenshot_20230107_162622.png](attachment:Screenshot_20230107_162622.png)]
# - []
# - [![Screenshot_20230107_162652.png](attachment:Screenshot_20230107_162652.png)]
# - []
# - [![Screenshot_20230107_162706.png](attachment:Screenshot_20230107_162706.png)]
# - []
# - [![Screenshot_20230107_162716.png](attachment:Screenshot_20230107_162716.png)]
# - []
# - Normalised Function

# %% [markdown]
# # **LOGOUT FORMAT**

# %% [markdown]
# - [![Screenshot_20230109_101842.png](attachment:Screenshot_20230109_101842.png)]
# - []
# - [![Screenshot_20230109_101934.png](attachment:Screenshot_20230109_101934.png)]
# - []
# - [![Screenshot_20230109_102007.png](attachment:Screenshot_20230109_102007.png)]
# - []
# - [![Screenshot_20230109_103149.png](attachment:Screenshot_20230109_103149.png)]
# - []
# - [![Screenshot_20230109_103212.png](attachment:Screenshot_20230109_103212.png)]
# - []
# - [![Screenshot_20230109_103219.png](attachment:Screenshot_20230109_103219.png)]

# %% [markdown]
# # **FORMS WEB/WEBapp**

# %% [markdown]
# - ![Screenshot_20230109_102413.png](attachment:Screenshot_20230109_102413.png)[]
# - []
# - ![Screenshot_20230109_102441.png](attachment:Screenshot_20230109_102441.png)[]
# - []
# - [![Screenshot_20230109_102448.png](attachment:Screenshot_20230109_102448.png)]
# - []
# - [![Screenshot_20230109_102455.png](attachment:Screenshot_20230109_102455.png)]
# - []
# - [![Screenshot_20230109_102505.png](attachment:Screenshot_20230109_102505.png)]
# - []
# - [![Screenshot_20230109_102514.png](attachment:Screenshot_20230109_102514.png)]
# - []
#
# - [![Screenshot_20230109_102538.png](attachment:Screenshot_20230109_102538.png)]
# - []
# - [![Screenshot_20230109_103614.png](attachment:Screenshot_20230109_103614.png)]

# %% [markdown]
# # pip install django-crispy-forms
# - [![Screenshot_20230109_110509.png](attachment:Screenshot_20230109_110509.png)]
# - [![Screenshot_20230109_125916.png](attachment:Screenshot_20230109_125916.png)]
# - [these format we can use in our projects from this sites https://getbootstrap.com/docs/4.1/getting-started/introduction/ ]
# - [![Screenshot_20230109_130619.png](attachment:Screenshot_20230109_130619.png)]
# - []
# - [![Screenshot_20230109_130619.png](attachment:Screenshot_20230109_130619.png)]
# - []
# - [![Screenshot_20230109_130708.png](attachment:Screenshot_20230109_130708.png)]
#
# - []
# - [![Screenshot_20230109_131128.png](attachment:Screenshot_20230109_131128.png)]

# %% [markdown]
# # **CREATING YOUR OWN BLOG**

# %% [markdown]
# First create the project and then
# - [![Screenshot_20230109_135455.png](attachment:Screenshot_20230109_135455.png)]
# - []
# - [![Screenshot_20230109_135514.png](attachment:Screenshot_20230109_135514.png)]
# - []
# - [![Screenshot_20230109_135522.png](attachment:Screenshot_20230109_135522.png)]
# - []
# - [![Screenshot_20230109_144530.png](attachment:Screenshot_20230109_144530.png)]
# - []
# - [![Screenshot_20230109_144720.png](attachment:Screenshot_20230109_144720.png)]

# %% [markdown]
# - [![Screenshot_20230109_161941.png](attachment:Screenshot_20230109_161941.png)]
# - []
# - [![Screenshot_20230109_161955.png](attachment:Screenshot_20230109_161955.png)]
# - []
# - [![Screenshot_20230109_162028.png](attachment:Screenshot_20230109_162028.png)]
# - []
# - [![Screenshot_20230109_162017.png](attachment:Screenshot_20230109_162017.png)]
# - []
# - [![Screenshot_20230109_162036.png](attachment:Screenshot_20230109_162036.png)]
# - []
# - [![Screenshot_20230109_162406.png](attachment:Screenshot_20230109_162406.png)]
# - []
# - [![Screenshot_20230109_162416.png](attachment:Screenshot_20230109_162416.png)]

# %% [markdown]
# ______________________________
# ### --------------------------Complete--------------------------------
