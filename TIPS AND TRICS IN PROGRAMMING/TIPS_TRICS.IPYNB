# %% [markdown]
# # 3 **TIPS AND TRICKS IN PROGRAMMING**
# ________________________
# - [1 **TIPS TO BECOME A GOOD PROGRAMMER**]
# - [2 **LOGICAL THINKING**]
# - [3 **TIPS TECHNIQUES1-2**]
# __________________________

# %% [markdown]
# ___________________
# #### 1 **TIPS TO BECOME A GOOD PROGRAMMER**
#
#      CONCEPTS
#                                       -->        UNDERSTAND
#
#                     [Without understanding a concepts never head to the next concepts.
#                          alwasys understand the concepts. the first thing u need to be understand is concepts and second one is logic.
#                                    so these two things are very important which helps u to become a good programmer ]
#       LOGICS
#
#
#                                       -->       PRACTICE
#
#                      [As soon you complete the concepts jsut go head and revise the concepts one and head to the next concepts .
#                                and also practice all the program you come accross. so you'll get the logic of the program ]
#
#
#                                      -->      SYNTAX & BASICS
#
#                   [1. from one programming language to the another programming language. like for example
#                            in C , C++, Python, Java] the syntax and basics are differs]
#
#
#      STACK OVERFLOW
#
#                                    -->       PROBLEM STATEMENTS
#
#                          [Once you're done with all those concepts and practice . you can just go a head and solve the problem. whenever we solve the problem we get error or you might get stuck so at those time you can take help from these two sites which are stack overflow and github. so we can rectify the problem. ]
#
#      GITHUB
#
#
#                                    -->       KEEP IT SIMPLE
#
#                               other must be able to read your programme
#                                         always use comments. whenever is necessary  ]

# %% [markdown]
# _______________________________
# #### 2 **LOGICAL THINKING**
#
#         BREAK THE PROBLEM INTO PARTS
#
#
#                                                                 SOLVE PROBLEM
#
#         USE FLOWCHARTS
#
#                                 1. IN A LOCALITY, ONLY PEOPLE ABOVE/EQUAL TO THAT OF THE AGE 18 ARE ELIGIBLE TO CAST THEIR VOTES, WHEREAS THE PEOPLE BELOW AGE 18 ARE NOT ELEGIBLE TO VOTE INSTEAD THEY CAN CAST THEIR WILLINGNESS IN THE SUGGESTION BOX.
#
# _______________________________
#         BREAK THE PROBLEM                               IN A LOCALITY , ONLY PEOPLE
#
#                                                 - ABOVE / EQUAL TO THAT OF THE AGE 18 ARE ELIGIBLE TO CAST THEIR VOTES
#
#                                                  WHEREAS THE PEOPLE
#
#                                                 - BELOW AGE 18 ARE NOT ELIGIBLE TO VOTE INSTEAD THEY CAN CAST THEIR WILLINGNESS IN THE SUGGESTION BOX.
# - [![Screenshot_20230121_151758.png](attachment:Screenshot_20230121_151758.png)]
# ______________________________
#
#
#                 GAMES, APPS                             WORK ON PROJECTS
#
#                                                 [WORKING ON PROJECTS : IF WE WANT TO DEVELOP SOME APPS AND WEBSITE.
#                                                 APPLY ALL THE LOGICS YOU KNOW OR AWARE. PROJECTS ALWAYS HELP YOU TO
#                                                 DEVELOP THE PROGRAMMING CAPABILITES THAT YOU HAVE .]

# %% [markdown]
# _____________________
# #### 3 **TIPS TECHNIQUES1-2**

# %%
# quite simple 
def add(a,b):
    return a+b
addition = add(12,2)
print(addition)


# not readable 
def az(g,h):
    return g+h
qwe = az(4,7)
print(qwe)
# Out:
# 14

# %%
x = 7
y = 4
class Post:
    if y<3:
        print('Invalid Input')
    else:
        print('\n',y)

def post():
    if (x<3):
        print('Invalid Input')
    else:
        print('\n',x)

post()
# Out:
#  4
#
#  7
