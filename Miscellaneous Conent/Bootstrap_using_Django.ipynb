# %% [markdown]
# ____________________________
# - [**Updating entries in Django with UpdateView**]()
# - [**Bootstrap part 1 : Introduction to bootstrap**]()
# - [**Bootstrap part 2 : Adding Bootstrap To our site**]()
# - [**Bootstrap part 3 : Bootstrap Grid System**]()
# - [**Bootstrap part 4 : Grid classes**]()
# - [**Bootstrap part 5 : Grid column offset**]()
# - [**Bootstrap part 6 : Making image Responsive**]()
# - [**Bootstrap part 7 : Nesting of Rows & Coolumns**]()
# - **Den[startproject]- dentries[app]-user[Den]-passward[Den]**
# ___________________________

# %% [markdown]
# ____________
# #### **Updating entries in Django with UpdateView**
# **Check the entries in the Den projects**
# - [![Screenshot_20230123_162545.png](attachment:Screenshot_20230123_162545.png)]
# - [![Screenshot_20230123_162555.png](attachment:Screenshot_20230123_162555.png)]
# - [![Screenshot_20230123_162614.png](attachment:Screenshot_20230123_162614.png)]

# %% [markdown]
# ______________
# #### **Bootstrap part 1 : Introduction to bootstrap**

# %% [markdown]
# - [![Screenshot_20230124_115710.png](attachment:Screenshot_20230124_115710.png)]

# %% [markdown]
# ___________________
# #### **Bootstrap part 2 : Adding Bootstrap To our site**

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Heading-Section</title>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/css/bootstrap.min.css" integrity="sha384-xOolHFLEh07PJGoPkLv1IbcEPTNtaed2xpHsD9ESMhqIYd0nLMwNLD69Npy4HI+N" crossorigin="anonymous">
# </head>
# <body>
#     <h1>Heading</h1>
# </body>
# </html>

# %% [markdown]
# ___________________
# #### **Bootstrap part 3 : Bootstrap Grid System**

# %% [markdown]
# - [![Screenshot_20230124_124726.png](attachment:Screenshot_20230124_124726.png)]
# - [![Screenshot_20230124_124147.png](attachment:Screenshot_20230124_124147.png)]

# %% [markdown]
# _____________________
# #### **Bootstrap part 4 : Grid classes**

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Heading-Section</title>
#     <!-- <link rel="stylesheet" type="text/css" href="style.css"> -->
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/css/bootstrap.min.css" integrity="sha384-xOolHFLEh07PJGoPkLv1IbcEPTNtaed2xpHsD9ESMhqIYd0nLMwNLD69Npy4HI+N" crossorigin="anonymous">
#     <style>
#         .newDiv{
#         margin: 5px;
#         height: 200px;
#         background-color: rgb(253, 224, 188);
#         text-align: center;
#         font-size: large;
# }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="row">
#             <div class="col-md-6">       <!-- md/xl - [medium device/ medium resolution/size and medium devices have medium resolution.=>700pixels1920*1080
#                 md is suitable for any device width > 768pixels] -->
#                 <div class="newDiv">
#                     Left Column
#                 </div>
#             </div>
#             <div class="col-md-6">
#                 <div class="newDiv">
#                     Right Column
#                 </div>
#             </div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# - [![Screenshot_20230124_133013.png](attachment:Screenshot_20230124_133013.png)]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0"> -->
#     <title>Heading-Section</title>
#     <!-- <link rel="stylesheet" type="text/css" href="style.css"> -->
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/css/bootstrap.min.css" integrity="sha384-xOolHFLEh07PJGoPkLv1IbcEPTNtaed2xpHsD9ESMhqIYd0nLMwNLD69Npy4HI+N" crossorigin="anonymous">
#     <style>
#         .newDiv{
#         margin: 5px;
#         height: 200px;
#         background-color: rgb(253, 224, 188);
#         text-align: center;
#         font-size: large;
# }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="row">
#             <div class="col-md-6  col-sm-6">
#                 <div class="newDiv">
#                     Left Column
#                 </div>
#             </div>
#             <div class="col-md-6 col-sm-6">
#                 <div class="newDiv">
#                     Right Column
#                 </div>
#             </div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# - [![Screenshot_20230124_135201.png](attachment:Screenshot_20230124_135201.png)]
# - [![Screenshot_20230124_135318.png](attachment:Screenshot_20230124_135318.png)]
# - [![Screenshot_20230124_141106.png](attachment:Screenshot_20230124_141106.png)]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0"> -->
#     <title>Heading-Section</title>
#     <!-- <link rel="stylesheet" type="text/css" href="style.css"> -->
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/css/bootstrap.min.css" integrity="sha384-xOolHFLEh07PJGoPkLv1IbcEPTNtaed2xpHsD9ESMhqIYd0nLMwNLD69Npy4HI+N" crossorigin="anonymous">
#     <style>
#         .newDiv{
#         margin: 5px;
#         height: 200px;
#         background-color: rgb(253, 224, 188);
#         text-align: center;
#         font-size: large;
# }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="row">
#             <div class="col-lg-6 col-md-8">
#                 <div class="newDiv">
#                     Column 1
#                 </div>
#             </div>
#             <div class="col-lg-6 col-md-4">
#                 <div class="newDiv">
#                     Column 2
#                 </div>
#             </div>
#             <div class="col-lg-6 col-md-8">
#                 <div class="newDiv">
#                     Column 3
#                 </div>
#             </div>
#             <div class="col-lg-6 col-md-4">
#                 <div class="newDiv">
#                     Column 4
#                 </div>
#             </div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# __________________
# #### **Bootstrap part 5 : Grid column offset**

# %% [markdown]
# - [![Screenshot_20230124_142147.png](attachment:Screenshot_20230124_142147.png)]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0"> -->
#     <title>Heading-Section</title>
#     <!-- <link rel="stylesheet" type="text/css" href="style.css"> -->
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/css/bootstrap.min.css" integrity="sha384-xOolHFLEh07PJGoPkLv1IbcEPTNtaed2xpHsD9ESMhqIYd0nLMwNLD69Npy4HI+N" crossorigin="anonymous">
#     <style>
#         .newDiv{
#         margin: 5px;
#         height: 200px;
#         background-color: rgb(188, 240, 253);
#         text-align: center;
#         font-size: large;
# }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="row">
#             <div class="col-lg-3 offset-6">
#                 <div class="newDiv">
#                     Column 1
#                 </div>
#             </div>
#         </div>
#         <div class="row">
#             <div class="col-lg-3">
#                 <div class="newDiv">
#                     Column 1
#                 </div>
#             </div>
#             <div class="col-lg-3">
#                 <div class="newDiv">
#                     Column 2
#                 </div>
#             </div>
#             <div class="col-lg-3">
#                 <div class="newDiv">
#                     Column 3
#                 </div>
#             </div>
#             <div class="col-lg-3">
#                 <div class="newDiv">
#                     Column 4
#                 </div>
#             </div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# ________________
# #### **Bootstrap part 6 : Making image Responsive**

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0"> -->
#     <title>Heading-Section</title>
#     <!-- <link rel="stylesheet" type="text/css" href="style.css"> -->
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/css/bootstrap.min.css" integrity="sha384-xOolHFLEh07PJGoPkLv1IbcEPTNtaed2xpHsD9ESMhqIYd0nLMwNLD69Npy4HI+N" crossorigin="anonymous">
#     <style>
#         .newDiv{
#         margin: 5px;
#         height: 200px;
#         background-color: rgb(188, 240, 253);
#         text-align: center;
#         font-size: large;
# }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <!-- <img class="img-fluid" src="https://images.unsplash.com/photo-1674531512182-c7a0e47ae57a?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1887&q=80"> -->
#         <img class="img-fluid" src="dell.jpg">
#         <img class="img-fluid" src="hibachi.jpg">
#         <img class="float-left" src="eberhard-grossgasteiger-_VPKNWIgIFo-unsplash.jpg" alt="">
#     </div>
# </body>
# </html>

# %% [markdown]
# - [![Screenshot_20230124_151214.png](./Pic/Screenshot_20230123_162614.png)]

# %% [markdown]
# ________________
# #### **Bootstrap part 7 : Nesting of Rows & Coolumns**

# %% [markdown]
# - [![Screenshot_20230124_152939.png](attachment:Screenshot_20230124_152939.png)]
# - [![Screenshot_20230124_160158.png](attachment:Screenshot_20230124_160158.png)]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0"> -->
#     <title>Heading-Section</title>
#     <!-- <link rel="stylesheet" type="text/css" href="style.css"> -->
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.6.2/dist/css/bootstrap.min.css" integrity="sha384-xOolHFLEh07PJGoPkLv1IbcEPTNtaed2xpHsD9ESMhqIYd0nLMwNLD69Npy4HI+N" crossorigin="anonymous">
#     <style>
#         .newDiv{
#             margin: 5px;
#             height: 200px;
#             background-color: rgb(252, 221, 221);
#             text-align: center;
#             font-size: large;
#         }
#         .maincontent{
#             margin: 5px;
#             height: 410px;
#             background-color: rgb(241, 216, 245);
#             text-align: center;
#             font-size: large;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="row">
#             <div class="col-md-3">
#                 <div class="row">
#                     <div class="col-md-12 newDiv">
#                         Section 1
#                     </div>
#                 </div>
#                 <div class="row">
#                     <div class="col-md-12 newDiv">
#                         Section 2
#                     </div>
#                 </div>
#             </div>
#             <div class="col-md-6">
#                 <div class="maincontent newDiv">
#                     Section 3
#                 </div>
#             </div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# ____________________
#                                                                                             Complete
