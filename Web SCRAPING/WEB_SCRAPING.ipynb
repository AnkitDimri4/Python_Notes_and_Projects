# %% [markdown]
# -  [Into to Web Scraping](#into-to-web-scraping)<br>
# - [UNICODE AND ASCII](#unicode-and-ascii)<br>

# %% [markdown]
# _____________________
# # **Web Scraping**
# _____________________
# Process of extracting data from a websites.

# %% [markdown]
# _____________________
# # **Retriving DATA**
# _____________________
# 1. ENCODE
# 2. DECODE

# %% [markdown]
# # **Into to Web Scraping**
# - [![Screenshot_20230116_111925.png](attachment:Screenshot_20230116_111925.png)]
# - []
# - [![Screenshot_20230116_112245.png](attachment:Screenshot_20230116_112245.png)]

# %% [markdown]
# _______________________
# # **UNICODE AND ASCII**
# _______________________
# UNICODE CHARACTERS  & STRINGS
# - [![Screenshot_20230116_113250.png](attachment:Screenshot_20230116_113250.png)]
# - []
# - [![Screenshot_20230116_113613.png](attachment:Screenshot_20230116_113613.png)]
# - []
# - [![Screenshot_20230116_114252.png](attachment:Screenshot_20230116_114252.png)]
# - []
# - []
# - []
# - []

# %%
print(ord('a'))
print(ord('e'))
print(ord('7'))
print(ord('\n'))
# Out:
# 97
# 101
# 55
# 10

# %% [markdown]
# ______________
# # **Retrieving content from webpages**
# ______________

# %% [markdown]
# using library urllib. It does all the sockets work for us and it make  web pages look like files

# %%
import urllib3.request, urllib.parse, urllib.error
url = urllib.request.urlopen("http://localhost:8000/helloworld/")
for line in url:
    print(line.decode().strip())
# Out:
# Hello World!-Welcome

# %% [markdown]
# - [![Screenshot_20230116_135222.png](attachment:Screenshot_20230116_135222.png)]
# - []
# - [![Screenshot_20230116_135306.png](attachment:Screenshot_20230116_135306.png)]
# - []
# - []

# %% [markdown]
# ________________
# # **Getting the data**
# ________________

# %%
import requests
url = "http://localhost:8000/helloworld/"
response =requests.get(url=url)
print(dir(response))
print("\n")
print(dir(requests))
print("\n")
print(response.status_code)
print(response.headers)
print("\n")
print(response.request.headers)
print("\nYes")

# %% [markdown]
# ________________
# # **Stating the data using dictionaries**
# ________________

# %%
import requests
url = "http://localhost:8000/helloworld/"
user = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36 Edg/109.0.1518.52"
}
response = requests.get(url=url, headers = user)
print(response.request.headers)
print("\n")
print(type(response.content))

# %% [markdown]
# ________________
# # **Content**
# ________________
# to download the text, audio and video files

# %%
import requests
url = "http://localhost:8000/picture/images/Screenshot_20221218_025059.png"
user = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36 Edg/109.0.1518.52"
}
response = requests.get(url=url, headers = user)
# print(response.content) # much lengthy code 
# print(type(response.content))
pic = response.content
f = open("Screenshot_20221218_025059.png","wb") # writting bytes 
f.write(pic)
# Out:
# 2212

# %%
# # Import Required Module
# import requests
# from bs4 import BeautifulSoup

# # Web URL
# Web_url = "https://www.geeksforgeeks.org/make-notepad-using-tkinter/"

# # Get URL Content
# r = requests.get(Web_url)

# # Parse HTML Code
# soup = BeautifulSoup(r.content, 'html.parser')

# # List of all video tag
# video_tags = soup.findAll('video')
# print("Total ", len(video_tags), "videos found")

# if len(video_tags) != 0:
# 	for video_tag in video_tags:
# 		video_url = video_tag.find("a")['href']
# 		print(video_url)
# else:
# 	print("no videos found")

# %% [markdown]
# ____________
# # **Text**
# ____________

# %%
import requests
url = "http://localhost:8000/"
response = requests.get(url = url)

# print(response.text) # to show the html file 
print(type(response.text))
# Out:
# <!DOCTYPE html>
# <html>
#     <body>
#         <h1> My Blog </h1><br/><br/>
#         <h2> Latest Posts </h2>
#         <hr/>
#
#             <a href="/1/"><h3> NATURE </h3></a>
#             Jan. 9, 2023, 10:24 a.m.
#             <br/>
#                 <img src = "/picture/images/Screenshot_20221218_025059.png" height="400" width="400"/>
#             <br/>
#             <p> Nature is God&#x27;s Gift for us. </p>
#
#     </body>
# </html>
# <class 'str'>

# %% [markdown]
# ________________________
# # **Posting the Data**
# ________________________

# %%
import requests
url = "http://localhost:8000/Post/"
payload = {
    "title" : "Greetings",
    "content" : "Welcome to htmlPython."

}
response = requests.post(url = url, data = payload)
print(response.text)
# Out:
# {"detail":"Authentication credentials were not provided."}

# %% [markdown]
# _____________
# # **Params**
# _____________
# To get the urls and post data

# %%
import requests
url = "http://localhost:8000/Post/"
params = {
    "offset" : "15"

}
response = requests.get(url = url, params= params)
print(response.url)
print(response.text)
# Out:
# http://localhost:8000/Post/?offset=15
# {"detail":"Authentication credentials were not provided."}

# %% [markdown]
# - [![Screenshot_20230116_154718.png](attachment:Screenshot_20230116_154718.png)]

# %% [markdown]
# _________________________
# # **Filtering the data 1**
# _________________________
# pip install bs4
# pip install lxml

# %%
import requests
from bs4 import BeautifulSoup

def Extract(url):
    response = requests.get(url = url).content
    soup = BeautifulSoup(response, 'lxml') # type of html, htmlfilelib
    tag = soup.div
    print(tag)

Extract(url="https://en.wikipedia.org/wiki/Main_Page")
# Out:
# <div class="noprint" id="mw-page-base"></div>

# %% [markdown]
# **find the required dictionary**

# %%
import requests
from bs4 import BeautifulSoup

def Extract(url):
    response = requests.get(url = url).content
    soup = BeautifulSoup(response, 'lxml') # type of html, htmlfilelib
    # tag = soup.span
    tag = soup.find('div',{"id" :"mw-content-text"})
    print(tag)

Extract(url="https://en.wikipedia.org/wiki/Main_Page")

# %%
import requests
from bs4 import BeautifulSoup

def Extract(url):
    response = requests.get(url = url).content
    soup = BeautifulSoup(response, 'lxml') 
    tag = soup.find('table',{"class" :"infobox"})
    print(tag)
Extract(url="https://en.wikipedia.org/wiki/Wikipedia")

# %% [markdown]
# _____________________
# # **Filtering the Data 2**
# _____________________

# %%
import requests
from bs4 import BeautifulSoup

def Extract(url):
    response = requests.get(url = url).content
    soup = BeautifulSoup(response, 'lxml') # type of html, htmlfilelib
    # tag = soup.span
    tag = soup.find('div',{"id" :"mw-content-text"})
    h = tag.find("h2")
    print(h)

Extract(url="https://en.wikipedia.org/wiki/Main_Page")
# Out:
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>

# %% [markdown]
# _______________________
# # **Filtering the Data 3**
# _______________________
# - how to filter a data .. go the deeper

# %%
import requests
from bs4 import BeautifulSoup

def Extract(url):
    response = requests.get(url = url).content
    soup = BeautifulSoup(response, 'lxml') # type of html, htmlfilelib
    # tag = soup.span
    tag = soup.find('div',{"id" :"mw-content-text"})
    h = tag.find('h2',{'id':'mp-itn-h2'}).find("span")
    print(h,'\n')
    h = tag.find_all('h2','\n')
    print(h)

Extract(url="https://en.wikipedia.org/wiki/Main_Page")
# Out:
# <span class="mw-headline" id="In_the_news">In the news</span>
#
# []

# %% [markdown]
# ______________________
# # **Filtering of Data 4**
# ______________________
# how to add the content to the csv file

# %%
import requests
from bs4 import BeautifulSoup
import csv

def Extract(url):
    response = requests.get(url = url).content
    soup = BeautifulSoup(response, 'lxml') # type of html, htmlfilelib
    # tag = soup.span
    tag = soup.find('div',{"id" :"mw-content-text"})
    h = tag.find_all("h2")
    content = [span.text for span in h]
    print(content)

    with open("wiki.csv", "w") as csv_file:
        csv_write = csv.writer(csv_file)
        csv_write.writerow(content)


Extract(url="https://en.wikipedia.org/wiki/Main_Page")
# Out:
# ["From today's featured article", 'Did you know\xa0...', 'In the news', 'On this day', "Today's featured picture", 'Other areas of Wikipedia', "Wikipedia's sister projects", 'Wikipedia languages']

# %% [markdown]
# ________________________
# # **Downloading images 1**
# ________________________
# get the source code are required

# %%
import requests

user = input("Enter the Image name : ")
user_agent = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36" 
}
url = f"https://www.google.com/search?q={user}&source=lnms&sa=X&ved=2ahUkwjfx7KygebuAhUQOSsKHc17DsEQ_AUoAXoECBqQAw&biw=1536&bih=760"

response = requests.get(url = url, headers=user_agent).content
print(response)

# %% [markdown]
# __________________________
# # **Downloading images 2**
# __________________________
# get the link to download

# %%
import requests
import re # regular expression 
user = input("Enter the Image name : ")
user_agent = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36" 
}
url = f"https://www.google.com/search?q={user}&source=lnms&sa=X&ved=2ahUkwjfx7KygebuAhUQOSsKHc17DsEQ_AUoAXoECBqQAw&biw=1536&bih=760"


response = requests.get(url = url, headers=user_agent).text
print(response)
pattern = "\[\"https://.*\.jpg\",[0-9]+,[0-9]+\]"
# pattern = "\[\"https://\"]"
images = re.findall(pattern, response)
for image in images:
    # print(type(image))
    # print(eval(image)) # eval help us to convert the list 
    image_url = eval(image)
    print(image_url)


#["https://images.news18.com/ibnlive/uploads/2021/11/moon-surface-16373969274x3.jpg"]

# %% [markdown]
# __________________________
# # **Downloading images 3**
# __________________________

# %%
import requests
import re # regular expression 
user = input("Enter the Image name : ")
user_agent = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"  
}
url = f"https://www.google.com/search?q={user}&tbm=isch&ved=2ahUKEwi99dbbsM78AhXU_jgGHYLwC0YQ2-cCegQIABAA&oq=moon&gs_lcp=CgNpbWcQAzIECCMQJzIHCAAQsQMQQzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyBQgAEIAEOgcIIxDqAhAnOgQIABBDOggIABCxAxCDAVCNAliaEWCMFGgBcAB4BIAB8QWIAacfkgELMi0yLjIuMS4zLjGYAQCgAQGqAQtnd3Mtd2l6LWltZ7ABA8ABAQ&sclient=img&ei=WnbGY73gO9T94-EPguGvsAQ&bih=1007&biw=843"


response = requests.get(url = url, headers=user_agent).text
pattern = "\[\"https://.*\.jpg\",[0-9]+,[0-9]+\]"
# pattern = "\[\"https://\"]"
images = re.findall(pattern, response)
print(f"Total Images  : {len(images)}")
no_of_images = int(input("Number of images to be downloaded : "))
if images:
    for image in images[:no_of_images]: 
        image_url = eval(image)[0]
        response = requests.get(url=image_url).content
        print(response)
# Out:
# Total Images  : 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 15
#      13 images = re.findall(pattern, response)
#      14 print(f"Total Images  : {len(images)}")
# ---> 15 no_of_images = int(input("Number of images to be downloaded : "))
#      16 if images:
#      17     for image in images[:no_of_images]:
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# __________________________
# # **Downloading images 4**
# __________________________

# %%
import requests
import os
import re # regular expression 
user = input("Enter the Image name : ")
user_agent = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"  
}
url = f"https://www.google.com/search?q={user}&tbm=isch&ved=2ahUKEwi99dbbsM78AhXU_jgGHYLwC0YQ2-cCegQIABAA&oq=moon&gs_lcp=CgNpbWcQAzIECCMQJzIHCAAQsQMQQzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyBQgAEIAEOgcIIxDqAhAnOgQIABBDOggIABCxAxCDAVCNAliaEWCMFGgBcAB4BIAB8QWIAacfkgELMi0yLjIuMS4zLjGYAQCgAQGqAQtnd3Mtd2l6LWltZ7ABA8ABAQ&sclient=img&ei=WnbGY73gO9T94-EPguGvsAQ&bih=1007&biw=843"


response = requests.get(url = url, headers=user_agent).text
pattern = "\[\"https://.*\.jpg\",[0-9]+,[0-9]+\]"
# pattern = "\[\"https://\"]"
images = re.findall(pattern, response)
print(f"Total Images  : {len(images)}")
no_of_images = int(input("Number of images to be downloaded : "))

if images:
    if os.path.exists(user):
        os.mkdir(user)
        os.chdir(user)
    else:
        os.chdir(user)

    for image in images[:no_of_images]: 
        image_url = eval(image)[0]
        response = requests.get(url=image_url).content
        print(image_url)

# %%
import requests
import os
import re

user = input("Enter the Image name: ")
user_agent = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"
}

url = f"https://www.google.co.in/search?sca_esv=4250fb469ad3ef44&sxsrf=ACQVn0_4JpHYCZDzNYaLT-W1RTNx2EqXww:1713676664887&q={user}&uds=AMwkrPvMvw61UdLChSzcmVY6XcUVQe4EB1E_8E0Q2vL1xyQ0JKx98dE_EfG9Gr8RVClO3Fz819Zj9UMLMmY6dRCU3UGz0DGNftuKO-40209Wdst3yfcMqWqYgP7tkxhlMPi-53LG4y-ws9B-fNM6RkpdE4u_eh1rAOV1QUMCLfstxwRNISOhx_be-PDPuG3cDAFrmwf4jU_NSO5YBYbp2bWHtxEV_JBAbB-J-i493MlRfllcGxprzUCkqv0cMrVIGIldsaKUUKdvgQbeL2UrTyszWk5M2Icsum-J8s1HeFbfjUytqMTbkLo&udm=2&prmd=ivsnmbtz&sa=X&ved=2ahUKEwj3-vqGx9KFAxWjevUHHYSNAP4QtKgLegQIERAB"

response = requests.get(url=url, headers=user_agent).text
pattern = r'"(https://.*?\.jpg)"'
images = re.findall(pattern, response)
print(f"Total Images: {len(images)}")
no_of_images = int(input("Number of images to be downloaded: "))

if images:
    if not os.path.exists(user):
        os.mkdir(user)
    os.chdir(user)

    for index, image_url in enumerate(images[:no_of_images], 1):
        try:
            response = requests.get(url=image_url).content
            image_name = f"image_{index}.jpg"
            with open(image_name, "wb") as file:
                file.write(response)
            print(f"Downloaded image {index}")
        except Exception as e:
            print(f"Error downloading image {index}: {str(e)}")
# Out:
# Total Images: 59
# Downloaded image 1

# %% [markdown]
# _______________
# # **Price Tracer**
# _______________

# %%
import requests
from bs4 import BeautifulSoup

class Pricetracer:
    def __init__(self, url):
        self.url = url 
        self.user_agent = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36 Edg/*******2"}
        self.response = requests.get(url = self.url, headers=self.user_agent).text
        self.soup = BeautifulSoup(self.response, "lxml")
    
    def product_title(self):
        title = self.soup.find("span",{"id":"productTitle"})
        if title is not None:
            return title.text.strip()
        else:
            return "Tag not FOUND"
    def product_price(self):
        # pass
        price = self.soup.find("span",{"class":"a-price-whole"})
        if price is not None:
            return price.text.strip()
        else:
            return "Tag not FOUND"

device = Pricetracer(url="https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/dp/B09SH7FDKT/ref=sr_1_1_sspa?keywords=samsung%2Bgalaxy%2Bs22%2Bultra&qid=1673959099&sprefix=samsung%2Bgal%2Caps%2C440&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1")

print(device.product_title())
print(device.product_price())
# Out:
# Samsung Galaxy S22 Ultra 5G (Burgundy, 12GB, 256GB Storage) with No Cost EMI/Additional Exchange Offers
# 1,06,999.

# %% [markdown]
# _________Complete___________
